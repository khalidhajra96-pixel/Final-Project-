# %%
# ==============================
#      MULTI-CALCULATION PROGRAM
# ==============================

print("Welcome to the Multi-Calculation Program!")

# Ask user how many calculations they want to perform


times = int(input("How many calculations do you want to perform? "))

# Loop for each calculation
for i in range(times):

    print("\n==============================")
    print(f"        Calculation {i + 1}")
    print("==============================")

    # Input numbers
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    # Input operator
    op = input("Enter operator (+, -, *, /): ")

    # Perform calculation
    if op == "+":
        result = num1 + num2
        print(f"Result: {num1} + {num2} = {result}")

    elif op == "-":
        result = num1 - num2
        print(f"Result: {num1} - {num2} = {result}")

    elif op == "*":
        result = num1 * num2
        print(f"Result: {num1} * {num2} = {result}")

    elif op == "/":
        if num2 == 0:
            print("Error: Division by zero is not allowed!")

        else:
            result = num1 / num2
            print(f"Result: {num1} / {num2} = {result}")

    else:
        print("Error: Invalid operator!")

print("\nAll calculations are complete. Thank you for using the program!")
# Out:
# Welcome to the Multi-Calculation Program!
# How many calculations do you want to perform? 2
#
# ...
#         Calculation 1
# ...
# Enter first number: 14
# Enter second number: 43
# Enter operator (+, -, *, /): /
# Result: 14.0 / 43.0 = 0.32558139534883723
#
# ...
#         Calculation 2
# ...
# Enter first number: 45
# Enter second number: 32
# Enter operator (+, -, *, /): *
# Result: 45.0 * 32.0 = 1440.0
#
# All calculations are complete. Thank you for using the program!
